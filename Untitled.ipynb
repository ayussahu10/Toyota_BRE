# %%
import streamlit as st
import pandas as pd
from ast import literal_eval
import chromadb
from chromadb.utils import embedding_functions
import openai
from pathlib import Path
import base64

# %%
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
        api_key="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",
        model_name="text-embedding-ada-002"
        )

# %%
file400 = pd.read_csv('business_rules_pasb400_embeddings.csv')
file450 = pd.read_csv('business_rules_pasb450_embeddings.csv')
file776 = pd.read_csv('business_rules_pasb776_embeddings.csv')

# %%
df = pd.concat([file400,file450,file776])
df.drop_duplicates()
# Out:
#    Annotation Type        Category        State  Rule Sequence Number  \
# 0             RULE  Technical Rule    CANDIDATE                   0.1
# 1             RULE  Technical Rule    CANDIDATE                   0.2
# 2             RULE  Technical Rule    CANDIDATE                   0.3
# 3             RULE  Technical Rule    CANDIDATE                   1.1
# 4             RULE  Technical Rule    CANDIDATE                   1.2
# ..             ...             ...          ...                   ...
# 21            RULE    Process Rule  IN_ANALYSIS                   6.1
# 22            RULE    Process Rule  IN_ANALYSIS                   6.2
# 23            RULE    Process Rule    CANDIDATE                   7.1
# 24            RULE    Process Rule    CANDIDATE                   7.2
# 25            RULE    Process Rule    CANDIDATE                   7.3
#
#                                Annotation Description  \
# 0   Declare C1-DENVCAL cursor:\nThis code declares...
# ...

# %%
df=df.rename(columns = {'Annotation Type':'Annotation_Type'})
df=df.rename(columns = {'Rule Sequence Number':'Rule_Sequence_Number'})
df=df.rename(columns = {'Annotation Description':'Annotation_Description'})

# %%
metadf = df[['Annotation_Type','Category','State','Rule_Sequence_Number']]

# %%
data = metadf.to_dict(orient='records')

# %%
data
# Out:
# [{'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 0.1},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 0.2},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 0.3},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 1.1},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 1.2},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 1.3},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Technical Rule',
#   'State': 'CANDIDATE',
#   'Rule_Sequence_Number': 2.1},
#  {'Annotation_Type': 'RULE',
#   'Category': 'Process Rule',
#   'State': 'IN_ANALYSIS',
#   'Rule_Sequence_Number': 2.2},
# ...

# %%
df["id"] = df.index + 1

# %%
df['Annotation_Description'] = df['Annotation_Description'].astype(str)

# %%
result_df = df[['Annotation_Description', 'embeddings','id']]
result_df['id'] = result_df['id'].apply(str)
# Out:
# C:\Users\ayussahu\AppData\Local\Temp\ipykernel_22372\436507262.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['id'] = result_df['id'].apply(str)

# %%
result_df['embeddings'] = result_df['embeddings'].apply(literal_eval)
# Out:
# Exiting: Cleaning up .chroma directory
# C:\Users\ayussahu\AppData\Local\Temp\ipykernel_22372\918115080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['embeddings'] = result_df['embeddings'].apply(literal_eval)

# %%
chroma_client = chromadb.Client()
chromdb_collection = chroma_client.create_collection(name='stories', embedding_function=openai_ef)
# Out:
# Running Chroma using direct local API.
# Using DuckDB in-memory for database. Data will be transient.
# Exiting: Cleaning up .chroma directory

# %%
chromdb_collection.add(
ids=result_df.id.tolist(),
embeddings=result_df.embeddings.tolist(),
# metadatas=[{"chapter": "3", "verse": "16"},],
documents=result_df.Annotation_Description.tolist()
)

# %%
def retreive_relevant_docs(chromdb_collection,prompt):
    title_query_result = chromdb_collection.query(
        query_texts=prompt,
        n_results=10
    )
    return title_query_result

# %%
def get_response(prompt, system, temperature = 1.0):
    response = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo",
        messages = [{"role": "user", "content": prompt},
                {"role": "system", "content": system}],
        temperature = temperature
    )
    return response['choices'][0]['message']['content']

# %%
def create_context(df):
    context = ''
    for i,doc in enumerate(df['documents']):
        context += f"Document {i+1}:\n{doc}\n"
    return context

# %%
user_query = 'Provide a list of cursor names used in the code.'

# %%
title_query_result = retreive_relevant_docs(chromdb_collection,[user_query])

context = create_context(title_query_result)
# print(context)

# generate RAG responses by passing top relevant documents
system_prompt = """You are an intelligent question answer assistant. Your task is to answer user 
questions based on the context provided to you. Display the reason of your answers along with 
accuracy score as well."""

message_prompt = f"""
Question:
```
{user_query}
```

Context:
```
{context}
```

Answer:

"""

response = get_response(message_prompt, system_prompt, temperature = 0.9)

# %%
print(response)
# Out:
# Cursor names used in the code:
#
# 1. C1-DENVCAL (mentioned 4 times)
# 2. C2-MDSCPCO (mentioned twice)
# 3. C3-MDSITCR (mentioned twice)
# 4. C2-ITFFCTP (mentioned once)

# %%
data = {'Column1': [1, 2, 3],
        'Column2': ['A', 'B', 'C'],
        'Column3': [True, False, True]}
df = pd.DataFrame(data)

# Convert each row into a dictionary
dict_list = df.to_dict(orient='records')

# Display the list of dictionaries
print(dict_list)
# Out:
# [{'Column1': 1, 'Column2': 'A', 'Column3': True}, {'Column1': 2, 'Column2': 'B', 'Column3': False}, {'Column1': 3, 'Column2': 'C', 'Column3': True}]

# %%
metadf = Annotation Type	Category	State	Rule Sequence Number
